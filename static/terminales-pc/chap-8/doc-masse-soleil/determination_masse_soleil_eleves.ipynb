# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # Détermination de la masse du Soleil

# %% [markdown]
# Q1 - Valeurs astronomiques

# %%
T = [ ... ]                         # en années
a = [ ... ]     # en m

# %% [markdown]
# Constantes

# %%
nbre_jours_par_an = 365.25
nbre_secondes_par_jour = 86400
G = 6.674e-11
pi = np.pi

# %% [markdown]
# Q2 - Convertir chaque période en secondes

# %%
for i in range(len(T)):
    T[i] = ...

# %% [markdown]
# Q3 - Élever au carré chaque valeur de la periode

# %%
T_carre = []

for periode in T:
    ...

# %% [markdown]
# Q4 - Élever au cube chaque demi-grand axe

# %%
a_cube = []

for demi_grand_axe in a:
    ...

# %% [markdown]
# Q5 - Tracer $T^2$ en fonction de $a^3$.

# %%
sns.set()
plt.figure(figsize=(8, 6), dpi=100)
plt.plot( ... , ... , 'o')
plt.xlabel("$a^3 \ (\mathrm{m}^3)$")
plt.ylabel("$T^2 \ (\mathrm{s}^2)$")
plt.show()

# %% [markdown]
# Q6 - Réaliser la modélisation

# %%
# Nouvelles dates pour l'affichage des grandeurs modélisées
a_cube_mod = np.linspace(min(a_cube), max(a_cube), 101)

# Fonction modèle pour le comportement de T^2 en fonction de a^3
def modele(x, a):
    return ...

# Détermination des paramètres optimaux pour T^2 en fonction de a^3
popt, pcov = curve_fit(modele, a_cube, T_carre)
a_mod = popt[0]

# Valeurs de T^2 modélisées
T_carre_mod = modele(a_cube_mod, a_mod)

print(f"Pente de la modélisation : {a_mod}")

# %% [markdown]
# Q7 - Affichage des courbes

# %%
plt.figure(figsize=(8, 6), dpi=100)
plt.plot( ... , ... , 'o')
plt.plot( ... , ... , '-')
plt.xlabel("$a^3 \ (\mathrm{m}^3)$")
plt.ylabel("$T^2 \ (\mathrm{s}^2)$")
plt.show()

# %% [markdown]
# Q8 - Détermination de la masse du Soleil

# %%
MS = ...
print(f"La masse du Soleil est : {MS} kg")
